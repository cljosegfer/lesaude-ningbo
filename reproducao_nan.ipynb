# %% [markdown]
# # setup

# %%
from ecgprep import preprocess, read_ecg
import h5py
import pandas as pd
import tqdm
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
input_file = 'RECORDS.txt'
root_dir = 'WFDB_ShaoxingUniv'
out_file = 'ningbo.h5'

fmt = 'wfdb'

new_freq = 400
new_len = 4096
scale = 2
use_all_leads = True
remove_baseline = False
remove_powerline = None

# %% [markdown]
# # draft

# %%
all_leads = ['DI', 'DII', 'DIII', 'AVR', 'AVL', 'AVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']

# %%
files = pd.read_csv(input_file, header=None).values.flatten()
folder = root_dir
n = len(files)

# %%
for i, f in enumerate(tqdm.tqdm(files)):
    break
i, f
# Out:
#   0%|          | 0/45152 [00:00<?, ?it/s]
# (0, 'JS00001')

# %%
ecg, sample_rate, leads = read_ecg.read_ecg(os.path.join(folder, f), format = fmt)
ecg, sample_rate, leads
# Out:
# (array([[-0.254, -0.254, -0.254, ..., -0.034,  0.024,  0.005],
#         [ 0.264,  0.264,  0.264, ..., -0.068, -0.049, -0.034],
#         [ 0.517,  0.517,  0.517, ..., -0.034, -0.073, -0.039],
#         ...,
#         [ 0.81 ,  0.81 ,  0.81 , ..., -0.205, -0.2  , -0.171],
#         [ 0.81 ,  0.81 ,  0.81 , ..., -0.2  , -0.195, -0.166],
#         [ 0.527,  0.527,  0.527, ...,  0.102,  0.093,  0.112]]),
#  500,
#  ['I', 'II', 'III', 'aVR', 'aVL', 'aVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6'])

# %%
np.isnan(ecg).any()
# Out:
# False

# %%
ecg_preprocessed, new_rate, new_leads = preprocess.preprocess_ecg(ecg, sample_rate, all_leads, # different lead names
                                                                          new_freq=new_freq,
                                                                          new_len=new_len,
                                                                          scale=scale,
                                                                          use_all_leads=use_all_leads,
                                                                          remove_baseline=remove_baseline,
                                                                          remove_powerline=remove_powerline)
ecg_preprocessed, new_rate, new_leads
# Out:
# (array([[-0.45662999, -0.52572182, -0.49735178, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.47596687,  0.54495072,  0.52134413, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.93259686,  1.07067254,  1.01869592, ...,  0.        ,
#           0.        ,  0.        ],
#         ...,
#         [ 1.46068218,  1.67124455,  1.60023106, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.46065339,  1.67128349,  1.60013837, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.94859643,  1.09061578,  1.03516844, ...,  0.        ,
#           0.        ,  0.        ]]),
#  400,
#  ['DI',
#   'DII',
#   'DIII',
#   'AVR',
#   'AVL',
#   'AVF',
#   'V1',
#   'V2',
#   'V3',
#   'V4',
#   'V5',
#   'V6'])

# %%
np.isnan(ecg_preprocessed).any()
# Out:
# False

# %% [markdown]
# # assert

# %%
# for i, f in enumerate(tqdm.tqdm(files)):
#     ecg, sample_rate, leads = read_ecg.read_ecg(os.path.join(folder, f), format=fmt)
#     assert not np.isnan(ecg).any()
#     ecg_preprocessed, new_rate, new_leads = preprocess.preprocess_ecg(ecg, sample_rate, leads,
#                                                                             new_freq=new_freq,
#                                                                             new_len=new_len,
#                                                                             scale=scale,
#                                                                             use_all_leads=use_all_leads,
#                                                                             remove_baseline=remove_baseline,
#                                                                             remove_powerline=remove_powerline)
#     assert not np.isnan(ecg_preprocessed).any()
# Out:
#  23%|██▎       | 10365/45152 [01:10<03:55, 147.48it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 for i, f in enumerate(tqdm.tqdm(files)):
#       2     ecg, sample_rate, leads = read_ecg.read_ecg(os.path.join(folder, f), format=fmt)
# ----> 3     assert not np.isnan(ecg).any()
#       4     ecg_preprocessed, new_rate, new_leads = preprocess.preprocess_ecg(ecg, sample_rate, leads,
#       5                                                                             new_freq=new_freq,
#       6                                                                             new_len=new_len,
#    (...)
#       9                                                                             remove_baseline=remove_baseline,
#      10                                                                             remove_powerline=remove_powerline)
#      11     assert not np.isnan(ecg_preprocessed).any()
#
# AssertionError:

# %%
# np.isnan(ecg).any(), np.isnan(ecg_preprocessed).any()
# Out:
# (True, True)

# %% [markdown]
# # log

# %%
log = []
names = []
for i, f in enumerate(tqdm.tqdm(files)):
    ecg, sample_rate, leads = read_ecg.read_ecg(os.path.join(folder, f), format=fmt)
    ecg_preprocessed, new_rate, new_leads = preprocess.preprocess_ecg(ecg, sample_rate, leads,
                                                                            new_freq=new_freq,
                                                                            new_len=new_len,
                                                                            scale=scale,
                                                                            use_all_leads=use_all_leads,
                                                                            remove_baseline=remove_baseline,
                                                                            remove_powerline=remove_powerline)
    # log.append([f, np.isnan(ecg).any(), np.isnan(ecg_preprocessed).any()])
    log.append([np.isnan(ecg).any(), np.isnan(ecg_preprocessed).any()])
    names.append(f)
# Out:
# 100%|██████████| 45152/45152 [04:02<00:00, 186.29it/s]

# %%
array = np.array(log)
array, names
# Out:
# (array([[False, False],
#         [False, False],
#         [False, False],
#         ...,
#         [False, False],
#         [False, False],
#         [False, False]]),
#  ['JS00001',
#   'JS00002',
#   'JS00004',
#   'JS00005',
#   'JS00006',
#   'JS00007',
#   'JS00008',
#   'JS00009',
#   'JS00010',
#   'JS00011',
#   'JS00012',
#   'JS00013',
#   'JS00014',
#   'JS00015',
#   'JS00016',
#   'JS00017',
#   'JS00018',
#   'JS00019',
#   'JS00020',
#   'JS00021',
#   'JS00022',
#   'JS00023',
#   'JS00024',
#   'JS00025',
#   'JS00026',
#   'JS00027',
#   'JS00029',
#   'JS00030',
#   'JS00031',
#   'JS00032',
#   'JS00033',
#   'JS00034',
#   'JS00036',
#   'JS00037',
#   'JS00038',
#   'JS00039',
#   'JS00040',
#   'JS00041',
#   'JS00042',
#   'JS00043',
#   'JS00044',
#   'JS00045',
#   'JS00046',
#   'JS00047',
#   'JS00048',
#   'JS00049',
#   'JS00050',
#   'JS00051',
#   'JS00052',
#   'JS00053',
#   'JS00054',
#   'JS00055',
#   'JS00056',
#   'JS00057',
#   'JS00058',
#   'JS00059',
#   'JS00060',
#   'JS00061',
#   'JS00062',
#   'JS00063',
#   'JS00064',
#   'JS00065',
#   'JS00066',
#   'JS00067',
#   'JS00068',
#   'JS00069',
#   'JS00070',
#   'JS00071',
#   'JS00072',
#   'JS00073',
#   'JS00074',
#   'JS00075',
#   'JS00076',
#   'JS00077',
#   'JS00078',
#   'JS00079',
#   'JS00080',
#   'JS00081',
#   'JS00082',
#   'JS00083',
#   'JS00084',
#   'JS00085',
#   'JS00086',
#   'JS00087',
#   'JS00088',
#   'JS00089',
#   'JS00090',
#   'JS00091',
#   'JS00092',
#   'JS00093',
#   'JS00094',
#   'JS00095',
#   'JS00096',
#   'JS00097',
#   'JS00099',
#   'JS00100',
#   'JS00101',
#   'JS00102',
#   'JS00103',
#   'JS00104',
#   'JS00105',
#   'JS00106',
#   'JS00107',
#   'JS00108',
#   'JS00109',
#   'JS00110',
#   'JS00111',
#   'JS00112',
#   'JS00113',
#   'JS00114',
#   'JS00115',
#   'JS00116',
#   'JS00117',
#   'JS00118',
#   'JS00119',
#   'JS00120',
#   'JS00121',
#   'JS00122',
#   'JS00123',
#   'JS00124',
#   'JS00125',
#   'JS00126',
#   'JS00127',
#   'JS00128',
#   'JS00129',
#   'JS00130',
#   'JS00131',
#   'JS00132',
#   'JS00133',
#   'JS00134',
#   'JS00137',
#   'JS00138',
#   'JS00139',
#   'JS00140',
#   'JS00141',
#   'JS00142',
#   'JS00143',
#   'JS00144',
#   'JS00145',
#   'JS00146',
#   'JS00147',
#   'JS00148',
#   'JS00150',
#   'JS00151',
#   'JS00152',
#   'JS00153',
#   'JS00154',
#   'JS00155',
#   'JS00156',
#   'JS00157',
#   'JS00158',
#   'JS00159',
#   'JS00160',
#   'JS00161',
#   'JS00162',
#   'JS00163',
#   'JS00164',
#   'JS00165',
#   'JS00166',
#   'JS00167',
#   'JS00168',
#   'JS00169',
#   'JS00170',
#   'JS00171',
#   'JS00172',
#   'JS00173',
#   'JS00174',
#   'JS00175',
#   'JS00176',
#   'JS00177',
#   'JS00178',
#   'JS00179',
#   'JS00180',
#   'JS00181',
#   'JS00182',
#   'JS00183',
#   'JS00184',
#   'JS00185',
#   'JS00186',
#   'JS00187',
#   'JS00188',
#   'JS00189',
#   'JS00190',
#   'JS00191',
#   'JS00192',
#   'JS00193',
#   'JS00194',
#   'JS00195',
#   'JS00196',
#   'JS00197',
#   'JS00198',
#   'JS00199',
#   'JS00200',
#   'JS00201',
#   'JS00202',
#   'JS00203',
#   'JS00204',
#   'JS00205',
#   'JS00206',
#   'JS00207',
#   'JS00208',
#   'JS00209',
#   'JS00210',
#   'JS00211',
#   'JS00212',
#   'JS00213',
#   'JS00215',
#   'JS00216',
#   'JS00217',
#   'JS00218',
#   'JS00219',
#   'JS00220',
#   'JS00221',
#   'JS00222',
#   'JS00223',
#   'JS00224',
#   'JS00225',
#   'JS00226',
#   'JS00227',
#   'JS00228',
#   'JS00229',
#   'JS00230',
#   'JS00231',
#   'JS00232',
#   'JS00233',
#   'JS00234',
#   'JS00235',
#   'JS00236',
#   'JS00237',
#   'JS00238',
#   'JS00239',
#   'JS00240',
#   'JS00241',
#   'JS00242',
#   'JS00243',
#   'JS00244',
#   'JS00245',
#   'JS00247',
#   'JS00248',
#   'JS00249',
#   'JS00250',
#   'JS00251',
#   'JS00252',
#   'JS00253',
#   'JS00254',
#   'JS00255',
#   'JS00256',
#   'JS00257',
#   'JS00258',
#   'JS00259',
#   'JS00260',
#   'JS00261',
#   'JS00262',
#   'JS00263',
#   'JS00264',
#   'JS00265',
#   'JS00266',
#   'JS00267',
#   'JS00268',
#   'JS00269',
#   'JS00270',
#   'JS00271',
#   'JS00272',
#   'JS00273',
#   'JS00274',
#   'JS00276',
#   'JS00277',
#   'JS00278',
#   'JS00279',
#   'JS00280',
#   'JS00281',
#   'JS00282',
#   'JS00283',
#   'JS00284',
#   'JS00285',
#   'JS00286',
#   'JS00287',
#   'JS00288',
#   'JS00289',
#   'JS00290',
#   'JS00291',
#   'JS00292',
#   'JS00293',
#   'JS00294',
#   'JS00295',
#   'JS00296',
#   'JS00297',
#   'JS00298',
#   'JS00299',
#   'JS00300',
#   'JS00301',
#   'JS00302',
#   'JS00303',
#   'JS00304',
#   'JS00305',
#   'JS00306',
#   'JS00307',
#   'JS00308',
#   'JS00309',
#   'JS00310',
#   'JS00311',
#   'JS00312',
#   'JS00313',
#   'JS00314',
#   'JS00315',
#   'JS00316',
#   'JS00317',
#   'JS00318',
#   'JS00319',
#   'JS00320',
#   'JS00321',
#   'JS00322',
#   'JS00323',
#   'JS00324',
#   'JS00325',
#   'JS00326',
#   'JS00327',
#   'JS00328',
#   'JS00329',
#   'JS00330',
#   'JS00331',
#   'JS00332',
#   'JS00333',
#   'JS00334',
#   'JS00335',
#   'JS00336',
#   'JS00337',
#   'JS00338',
#   'JS00339',
#   'JS00340',
#   'JS00341',
#   'JS00342',
#   'JS00343',
#   'JS00344',
#   'JS00345',
#   'JS00346',
#   'JS00347',
#   'JS00348',
#   'JS00349',
#   'JS00350',
#   'JS00351',
#   'JS00352',
#   'JS00353',
#   'JS00354',
#   'JS00355',
#   'JS00356',
#   'JS00357',
#   'JS00358',
#   'JS00359',
#   'JS00360',
#   'JS00361',
#   'JS00362',
#   'JS00363',
#   'JS00364',
#   'JS00365',
#   'JS00366',
#   'JS00367',
#   'JS00368',
#   'JS00369',
#   'JS00370',
#   'JS00371',
#   'JS00372',
#   'JS00373',
#   'JS00374',
#   'JS00375',
#   'JS00376',
#   'JS00377',
#   'JS00378',
#   'JS00379',
#   'JS00380',
#   'JS00381',
#   'JS00382',
#   'JS00383',
#   'JS00384',
#   'JS00385',
#   'JS00386',
#   'JS00387',
#   'JS00388',
#   'JS00389',
#   'JS00390',
#   'JS00391',
#   'JS00392',
#   'JS00393',
#   'JS00394',
#   'JS00395',
#   'JS00396',
#   'JS00397',
#   'JS00398',
#   'JS00399',
#   'JS00400',
#   'JS00401',
#   'JS00402',
#   'JS00403',
#   'JS00404',
#   'JS00405',
#   'JS00406',
#   'JS00407',
#   'JS00408',
#   'JS00409',
#   'JS00410',
#   'JS00411',
#   'JS00412',
#   'JS00413',
#   'JS00414',
#   'JS00415',
#   'JS00417',
#   'JS00420',
#   'JS00421',
#   'JS00422',
#   'JS00423',
#   'JS00424',
#   'JS00425',
#   'JS00426',
#   'JS00427',
#   'JS00428',
#   'JS00429',
#   'JS00430',
#   'JS00431',
#   'JS00432',
#   'JS00433',
#   'JS00434',
#   'JS00435',
#   'JS00436',
#   'JS00437',
#   'JS00438',
#   'JS00439',
#   'JS00440',
#   'JS00441',
#   'JS00442',
#   'JS00444',
#   'JS00445',
#   'JS00446',
#   'JS00447',
#   'JS00448',
#   'JS00449',
#   'JS00450',
#   'JS00451',
#   'JS00452',
#   'JS00453',
#   'JS00454',
#   'JS00455',
#   'JS00456',
#   'JS00457',
#   'JS00458',
#   'JS00459',
#   'JS00461',
#   'JS00462',
#   'JS00463',
#   'JS00464',
#   'JS00465',
#   'JS00466',
#   'JS00467',
#   'JS00468',
#   'JS00469',
#   'JS00470',
#   'JS00471',
#   'JS00472',
#   'JS00473',
#   'JS00474',
#   'JS00475',
#   'JS00476',
#   'JS00477',
#   'JS00478',
#   'JS00479',
#   'JS00480',
#   'JS00481',
#   'JS00482',
#   'JS00483',
#   'JS00484',
#   'JS00485',
#   'JS00486',
#   'JS00487',
#   'JS00488',
#   'JS00490',
#   'JS00491',
#   'JS00492',
#   'JS00493',
#   'JS00494',
#   'JS00495',
#   'JS00496',
#   'JS00497',
#   'JS00498',
#   'JS00499',
#   'JS00500',
#   'JS00501',
#   'JS00502',
#   'JS00503',
#   'JS00504',
#   'JS00506',
#   'JS00507',
#   'JS00508',
#   'JS00509',
#   'JS00510',
#   'JS00511',
#   'JS00512',
#   'JS00513',
#   'JS00514',
#   'JS00515',
#   'JS00516',
#   'JS00517',
#   'JS00518',
#   'JS00519',
#   'JS00520',
#   'JS00521',
#   'JS00522',
#   'JS00523',
#   'JS00524',
#   'JS00525',
#   'JS00526',
#   'JS00527',
#   'JS00528',
#   'JS00529',
#   'JS00530',
#   'JS00531',
#   'JS00532',
#   'JS00533',
#   'JS00534',
#   'JS00535',
#   'JS00536',
#   'JS00537',
#   'JS00538',
#   'JS00540',
#   'JS00541',
#   'JS00543',
#   'JS00544',
#   'JS00545',
#   'JS00546',
#   'JS00547',
#   'JS00548',
#   'JS00549',
#   'JS00550',
#   'JS00552',
#   'JS00553',
#   'JS00554',
#   'JS00556',
#   'JS00557',
#   'JS00558',
#   'JS00559',
#   'JS00560',
#   'JS00561',
#   'JS00562',
#   'JS00563',
#   'JS00564',
#   'JS00565',
#   'JS00566',
#   'JS00567',
#   'JS00568',
#   'JS00569',
#   'JS00570',
#   'JS00571',
#   'JS00572',
#   'JS00573',
#   'JS00574',
#   'JS00575',
#   'JS00576',
#   'JS00577',
#   'JS00578',
#   'JS00579',
#   'JS00580',
#   'JS00581',
#   'JS00582',
#   'JS00583',
#   'JS00585',
#   'JS00586',
#   'JS00587',
#   'JS00588',
#   'JS00589',
#   'JS00590',
#   'JS00591',
#   'JS00592',
#   'JS00594',
#   'JS00595',
#   'JS00596',
#   'JS00597',
#   'JS00598',
#   'JS00599',
#   'JS00600',
#   'JS00601',
#   'JS00602',
#   'JS00603',
#   'JS00605',
#   'JS00606',
#   'JS00607',
#   'JS00608',
#   'JS00609',
#   'JS00610',
#   'JS00611',
#   'JS00612',
#   'JS00613',
#   'JS00614',
#   'JS00615',
#   'JS00616',
#   'JS00617',
#   'JS00618',
#   'JS00619',
#   'JS00620',
#   'JS00621',
#   'JS00623',
#   'JS00624',
#   'JS00625',
#   'JS00626',
#   'JS00627',
#   'JS00628',
#   'JS00629',
#   'JS00630',
#   'JS00631',
#   'JS00633',
#   'JS00634',
#   'JS00635',
#   'JS00636',
#   'JS00637',
#   'JS00638',
#   'JS00639',
#   'JS00640',
#   'JS00641',
#   'JS00642',
#   'JS00643',
#   'JS00644',
#   'JS00645',
#   'JS00646',
#   'JS00647',
#   'JS00648',
#   'JS00649',
#   'JS00651',
#   'JS00652',
#   'JS00653',
#   'JS00654',
#   'JS00655',
#   'JS00656',
#   'JS00657',
#   'JS00659',
#   'JS00660',
#   'JS00661',
#   'JS00662',
#   'JS00663',
#   'JS00664',
#   'JS00665',
#   'JS00666',
#   'JS00667',
#   'JS00668',
#   'JS00669',
#   'JS00670',
#   'JS00671',
#   'JS00672',
#   'JS00673',
#   'JS00674',
#   'JS00675',
#   'JS00677',
#   'JS00679',
#   'JS00680',
#   'JS00681',
#   'JS00682',
#   'JS00683',
#   'JS00684',
#   'JS00685',
#   'JS00686',
#   'JS00687',
#   'JS00688',
#   'JS00689',
#   'JS00690',
#   'JS00691',
#   'JS00692',
#   'JS00693',
#   'JS00694',
#   'JS00695',
#   'JS00696',
#   'JS00697',
#   'JS00698',
#   'JS00699',
#   'JS00700',
#   'JS00701',
#   'JS00702',
#   'JS00703',
#   'JS00704',
#   'JS00705',
#   'JS00706',
#   'JS00707',
#   'JS00708',
#   'JS00709',
#   'JS00711',
#   'JS00712',
#   'JS00713',
#   'JS00714',
#   'JS00716',
#   'JS00717',
#   'JS00718',
#   'JS00719',
#   'JS00720',
#   'JS00721',
#   'JS00722',
#   'JS00723',
#   'JS00724',
#   'JS00725',
#   'JS00726',
#   'JS00727',
#   'JS00728',
#   'JS00729',
#   'JS00731',
#   'JS00732',
#   'JS00734',
#   'JS00735',
#   'JS00736',
#   'JS00737',
#   'JS00738',
#   'JS00739',
#   'JS00740',
#   'JS00741',
#   'JS00742',
#   'JS00743',
#   'JS00744',
#   'JS00745',
#   'JS00746',
#   'JS00747',
#   'JS00748',
#   'JS00749',
#   'JS00750',
#   'JS00751',
#   'JS00752',
#   'JS00753',
#   'JS00754',
#   'JS00755',
#   'JS00756',
#   'JS00757',
#   'JS00758',
#   'JS00759',
#   'JS00760',
#   'JS00761',
#   'JS00762',
#   'JS00763',
#   'JS00764',
#   'JS00765',
#   'JS00766',
#   'JS00767',
#   'JS00768',
#   'JS00769',
#   'JS00770',
#   'JS00771',
#   'JS00772',
#   'JS00773',
#   'JS00774',
#   'JS00775',
#   'JS00776',
#   'JS00777',
#   'JS00778',
#   'JS00779',
#   'JS00780',
#   'JS00781',
#   'JS00782',
#   'JS00783',
#   'JS00784',
#   'JS00785',
#   'JS00786',
#   'JS00787',
#   'JS00788',
#   'JS00790',
#   'JS00791',
#   'JS00792',
#   'JS00793',
#   'JS00794',
#   'JS00795',
#   'JS00796',
#   'JS00797',
#   'JS00798',
#   'JS00799',
#   'JS00800',
#   'JS00801',
#   'JS00803',
#   'JS00804',
#   'JS00805',
#   'JS00806',
#   'JS00807',
#   'JS00808',
#   'JS00809',
#   'JS00810',
#   'JS00811',
#   'JS00812',
#   'JS00813',
#   'JS00814',
#   'JS00815',
#   'JS00816',
#   'JS00817',
#   'JS00818',
#   'JS00819',
#   'JS00820',
#   'JS00821',
#   'JS00822',
#   'JS00823',
#   'JS00824',
#   'JS00825',
#   'JS00827',
#   'JS00828',
#   'JS00829',
#   'JS00830',
#   'JS00831',
#   'JS00832',
#   'JS00833',
#   'JS00834',
#   'JS00835',
#   'JS00837',
#   'JS00838',
#   'JS00839',
#   'JS00840',
#   'JS00841',
#   'JS00842',
#   'JS00843',
#   'JS00844',
#   'JS00845',
#   'JS00846',
#   'JS00847',
#   'JS00848',
#   'JS00849',
#   'JS00850',
#   'JS00851',
#   'JS00852',
#   'JS00853',
#   'JS00854',
#   'JS00856',
#   'JS00857',
#   'JS00858',
#   'JS00859',
#   'JS00860',
#   'JS00861',
#   'JS00863',
#   'JS00864',
#   'JS00865',
#   'JS00866',
#   'JS00867',
#   'JS00868',
#   'JS00870',
#   'JS00871',
#   'JS00872',
#   'JS00873',
#   'JS00875',
#   'JS00876',
#   'JS00877',
#   'JS00878',
#   'JS00879',
#   'JS00880',
#   'JS00881',
#   'JS00882',
#   'JS00883',
#   'JS00884',
#   'JS00885',
#   'JS00886',
#   'JS00887',
#   'JS00888',
#   'JS00890',
#   'JS00891',
#   'JS00893',
#   'JS00894',
#   'JS00895',
#   'JS00896',
#   'JS00897',
#   'JS00898',
#   'JS00899',
#   'JS00900',
#   'JS00901',
#   'JS00902',
#   'JS00903',
#   'JS00904',
#   'JS00905',
#   'JS00906',
#   'JS00907',
#   'JS00909',
#   'JS00910',
#   'JS00911',
#   'JS00912',
#   'JS00913',
#   'JS00914',
#   'JS00915',
#   'JS00916',
#   'JS00917',
#   'JS00918',
#   'JS00919',
#   'JS00921',
#   'JS00922',
#   'JS00924',
#   'JS00925',
#   'JS00926',
#   'JS00927',
#   'JS00928',
#   'JS00929',
#   'JS00930',
#   'JS00931',
#   'JS00932',
#   'JS00933',
#   'JS00934',
#   'JS00935',
#   'JS00936',
#   'JS00937',
#   'JS00938',
#   'JS00939',
#   'JS00940',
#   'JS00941',
#   'JS00942',
#   'JS00943',
#   'JS00944',
#   'JS00945',
#   'JS00946',
#   'JS00947',
#   'JS00948',
#   'JS00949',
#   'JS00950',
#   'JS00951',
#   'JS00952',
#   'JS00953',
#   'JS00954',
#   'JS00955',
#   'JS00956',
#   'JS00958',
#   'JS00959',
#   'JS00960',
#   'JS00961',
#   'JS00962',
#   'JS00963',
#   'JS00964',
#   'JS00965',
#   'JS00966',
#   'JS00967',
#   'JS00968',
#   'JS00969',
#   'JS00970',
#   'JS00971',
#   'JS00972',
#   'JS00973',
#   'JS00974',
#   'JS00975',
#   'JS00976',
#   'JS00977',
#   'JS00978',
#   'JS00979',
#   'JS00980',
#   'JS00981',
#   'JS00982',
#   'JS00983',
#   'JS00984',
#   'JS00985',
#   'JS00986',
#   'JS00987',
#   'JS00988',
#   'JS00989',
#   'JS00990',
#   'JS00992',
#   'JS00993',
#   'JS00994',
#   'JS00995',
#   'JS00996',
#   'JS00997',
#   'JS00998',
#   'JS00999',
#   'JS01000',
#   'JS01001',
#   'JS01002',
#   'JS01003',
#   'JS01004',
#   'JS01005',
#   'JS01006',
#   'JS01007',
#   'JS01008',
#   'JS01009',
#   'JS01010',
#   'JS01011',
#   'JS01012',
#   'JS01013',
#   'JS01014',
#   'JS01016',
#   'JS01017',
#   'JS01018',
#   'JS01019',
#   'JS01020',
#   'JS01021',
#   'JS01022',
#   'JS01023',
#   'JS01024',
#   'JS01025',
#   'JS01026',
#   'JS01028',
#   'JS01030',
#   'JS01031',
#   'JS01032',
#   'JS01033',
#   'JS01034',
#   'JS01035',
#   'JS01036',
#   'JS01037',
#   'JS01038',
#   'JS01039',
#   'JS01040',
#   'JS01041',
#   'JS01042',
#   'JS01043',
#   'JS01044',
#   'JS01045',
#   'JS01046',
#   'JS01047',
#   'JS01048',
#   'JS01049',
#   'JS01050',
#   'JS01051',
#   'JS01052',
#   ...])

# %%
np.sum(array[:, 0]), np.sum(array[:, 1])
# Out:
# (97, 97)

# %%
np.unique(array[:, 0] == array[:, 1])
# Out:
# array([ True])

# %%
df = np.array(names)
df[array[:, 0]]
# Out:
# array(['JS10765', 'JS10767', 'JS10890', 'JS10951', 'JS11887', 'JS11897',
#        'JS11956', 'JS12751', 'JS13181', 'JS14161', 'JS14343', 'JS14627',
#        'JS14659', 'JS15624', 'JS16169', 'JS16222', 'JS16813', 'JS19309',
#        'JS19708', 'JS20330', 'JS20656', 'JS21144', 'JS21617', 'JS21668',
#        'JS21701', 'JS21853', 'JS21881', 'JS23116', 'JS23450', 'JS23482',
#        'JS23588', 'JS23786', 'JS23950', 'JS24016', 'JS25106', 'JS25322',
#        'JS25458', 'JS26009', 'JS26130', 'JS26145', 'JS26245', 'JS26605',
#        'JS26793', 'JS26843', 'JS26977', 'JS27034', 'JS27170', 'JS27271',
#        'JS27278', 'JS27407', 'JS27460', 'JS27835', 'JS27985', 'JS28075',
#        'JS28648', 'JS28757', 'JS33280', 'JS34479', 'JS34509', 'JS34788',
#        'JS34868', 'JS34879', 'JS35050', 'JS35065', 'JS35192', 'JS35654',
#        'JS35727', 'JS36015', 'JS36018', 'JS36189', 'JS36244', 'JS36568',
#        'JS36731', 'JS37105', 'JS37173', 'JS37176', 'JS37439', 'JS37592',
#        'JS37609', 'JS37781', 'JS38231', 'JS38252', 'JS41844', 'JS41908',
#        'JS41935', 'JS42026', 'JS42330', 'JS42400', 'JS42415', 'JS42614',
#        'JS42631', 'JS42676', 'JS43330', 'JS43400', 'JS43569', 'JS43710',
#        'JS44571'], dtype='<U7')

# %% [markdown]
# # physionet

# %%
ecg, sample_rate, leads = read_ecg.read_ecg('a-large-scale-12-lead-electrocardiogram-database-for-arrhythmia-study-1.0.0/WFDBRecords/11/113/JS10765', format=fmt)
ecg, sample_rate, leads, np.isnan(ecg).any()
# Out:
# (array([[ 2.0000e-02,  2.0000e-02,  2.0000e-02, ..., -1.8500e-01,
#          -1.9500e-01, -2.4400e-01],
#         [ 2.9000e-02,  2.9000e-02,  2.9000e-02, ..., -2.1000e-01,
#          -2.0000e-01, -2.0000e-01],
#         [ 1.0000e-02,  1.0000e-02,  1.0000e-02, ..., -2.4000e-02,
#          -5.0000e-03,  4.4000e-02],
#         ...,
#         [-3.9000e-02, -3.9000e-02, -3.9000e-02, ...,  3.4000e-02,
#           5.4000e-02,  5.9000e-02],
#         [-1.6934e+01, -1.6934e+01, -1.6934e+01, ..., -4.1500e-01,
#          -4.1500e-01, -3.9500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00, ...,  3.4000e-02,
#           3.9000e-02,  3.9000e-02]]),
#  500,
#  ['I', 'II', 'III', 'aVR', 'aVL', 'aVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6'],
#  True)

# %%
ecg_preprocessed, new_rate, new_leads = preprocess.preprocess_ecg(ecg, sample_rate, all_leads, # different lead names
                                                                          new_freq=new_freq,
                                                                          new_len=new_len,
                                                                          scale=scale,
                                                                          use_all_leads=use_all_leads,
                                                                          remove_baseline=remove_baseline,
                                                                          remove_powerline=remove_powerline)
ecg_preprocessed, new_rate, new_leads, np.isnan(ecg_preprocessed).any()
# Out:
# (array([[ 3.72808139e-02,  3.92626683e-02,  4.35779473e-02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.28287699e-02,  5.88950905e-02,  5.91054670e-02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 1.55479560e-02,  1.96324221e-02,  1.55275197e-02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [-7.02247167e-02, -8.06592296e-02, -7.66685410e-02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-3.04849064e+01, -3.49897658e+01, -3.32906842e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]),
#  400,
#  ['DI',
#   'DII',
#   'DIII',
#   'AVR',
#   'AVL',
#   'AVF',
#   'V1',
#   'V2',
#   'V3',
#   'V4',
#   'V5',
#   'V6'],
#  True)
